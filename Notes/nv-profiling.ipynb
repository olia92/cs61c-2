# %% [markdown]
# sp19-proj4-starter
# Makefile:
#     CFLAGS?=-Wall -march=native -std=c17 -g -pg
#     CC=nvc
#
# κώδικας χωρίς καθόλου openacc

# %%
$ nvprof --cpu-profiling on ./benchmark benchmark

# %% [markdown]
# ```
# RUNNING BENCHMARK ON 1200 PICTURES...
# Making network...
# Loading batches...
# Loading input batch 0...
# Running classification...
# 78.250000% accuracy
# 117674431 microseconds
#
# ======== CPU profiling result (bottom up):
# Time(%)      Time  Name
#  61.15%  71.9535s  ???
#  61.13%  71.9235s  | mcount
#  60.27%  70.9174s  | | volume_get
#  59.80%  70.3618s  | | | conv_forward
#  59.80%  70.3618s  | | | | net_forward
#  59.80%  70.3618s  | | | |   net_classify
#  59.80%  70.3618s  | | | |     run_classification
#  59.80%  70.3618s  | | | |       do_benchmark
#  59.80%  70.3618s  | | | |         main
#   0.26%  300.33ms  | | | relu_forward
#   0.26%  300.33ms  | | | | net_forward
#   0.26%  300.33ms  | | | |   net_classify
#   0.26%  300.33ms  | | | |     run_classification
#   0.26%  300.33ms  | | | |       do_benchmark
#   0.26%  300.33ms  | | | |         main
#   0.19%  220.24ms  | | | pool_forward
#   0.19%  220.24ms  | | | | net_forward
#   0.19%  220.24ms  | | | |   net_classify
#   0.19%  220.24ms  | | | |     run_classification
#   0.19%  220.24ms  | | | |       do_benchmark
#   0.19%  220.24ms  | | | |         main
#   0.03%  35.038ms  | | | copy_volume
#   0.03%  35.038ms  | | |   net_classify
#   0.03%  35.038ms  | | |     run_classification
#   0.03%  35.038ms  | | |       do_benchmark
#   0.03%  35.038ms  | | |         main
#   0.86%   1.0061s  | | volume_set
#   0.24%  280.31ms  | |   relu_forward
#   0.24%  280.31ms  | |   | net_forward
#   0.24%  280.31ms  | |   |   net_classify
#   0.24%  280.31ms  | |   |     run_classification
#   0.24%  280.31ms  | |   |       do_benchmark
#   0.24%  280.31ms  | |   |         main
#   0.20%  230.25ms  | |   conv_forward
#   0.20%  230.25ms  | |   | net_forward
#   0.20%  230.25ms  | |   |   net_classify
#   0.20%  230.25ms  | |   |     run_classification
#   0.20%  230.25ms  | |   |       do_benchmark
#   0.20%  230.25ms  | |   |         main
#   0.19%  225.25ms  | |   make_volume
#   0.19%  225.25ms  | |   | load_batch
#   0.19%  225.25ms  | |   |   run_classification
#   0.19%  225.25ms  | |   |     do_benchmark
#   0.19%  225.25ms  | |   |       main
#   0.15%  175.19ms  | |   load_batch
#   0.15%  175.19ms  | |   | run_classification
#   0.15%  175.19ms  | |   |   do_benchmark
#   0.15%  175.19ms  | |   |     main
#   0.05%   55.06ms  | |   pool_forward
#   0.05%   55.06ms  | |   | net_forward
#   0.05%   55.06ms  | |   |   net_classify
#   0.05%   55.06ms  | |   |     run_classification
#   0.05%   55.06ms  | |   |       do_benchmark
#   0.05%   55.06ms  | |   |         main
#   0.03%  40.044ms  | |   copy_volume
#   0.03%  40.044ms  | |     net_classify
#   0.03%  40.044ms  | |       run_classification
#   0.03%  40.044ms  | |         do_benchmark
#   0.03%  40.044ms  | |           main
#   0.01%  15.016ms  | malloc
#   0.01%  15.016ms  | | make_volume
#   0.01%  15.016ms  | |   load_batch
#   0.01%  15.016ms  | |     run_classification
#   0.01%  15.016ms  | |       do_benchmark
#   0.01%  15.016ms  | |         main
#   0.00%  5.0055ms  | ???
#   0.00%  5.0055ms  | | _IO_fread
#   0.00%  5.0055ms  | |   load_batch
#   0.00%  5.0055ms  | |     run_classification
#   0.00%  5.0055ms  | |       do_benchmark
#   0.00%  5.0055ms  | |         main
#   0.00%  5.0055ms  | free_volume
#   0.00%  5.0055ms  | | run_classification
#   0.00%  5.0055ms  | |   do_benchmark
#   0.00%  5.0055ms  | |     main
#   0.00%  5.0055ms  | __isoc99_fscanf
#   0.00%  5.0055ms  |   conv_load
#   0.00%  5.0055ms  |     load_cnn_snapshot
#   0.00%  5.0055ms  |       run_classification
#   0.00%  5.0055ms  |         do_benchmark
#   0.00%  5.0055ms  |           main
#  17.06%  20.0719s  volume_get
#  16.88%  19.8617s  | conv_forward
#  16.88%  19.8617s  | | net_forward
#  16.88%  19.8617s  | |   net_classify
#  16.88%  19.8617s  | |     run_classification
#  16.88%  19.8617s  | |       do_benchmark
#  16.88%  19.8617s  | |         main
#   0.09%  100.11ms  | relu_forward
#   0.09%  100.11ms  | | net_forward
#   0.09%  100.11ms  | |   net_classify
#   0.09%  100.11ms  | |     run_classification
#   0.09%  100.11ms  | |       do_benchmark
#   0.09%  100.11ms  | |         main
#   0.07%  85.093ms  | pool_forward
#   0.07%  85.093ms  | | net_forward
#   0.07%  85.093ms  | |   net_classify
#   0.07%  85.093ms  | |     run_classification
#   0.07%  85.093ms  | |       do_benchmark
#   0.07%  85.093ms  | |         main
#   0.02%  25.027ms  | copy_volume
#   0.02%  25.027ms  |   net_classify
#   0.02%  25.027ms  |     run_classification
#   0.02%  25.027ms  |       do_benchmark
#   0.02%  25.027ms  |         main
#  11.09%  13.0492s  mcount
#  10.89%   12.814s  | volume_get
#  10.78%  12.6888s  | | conv_forward
#  10.78%  12.6888s  | | | net_forward
#  10.78%  12.6888s  | | |   net_classify
#  10.78%  12.6888s  | | |     run_classification
#  10.78%  12.6888s  | | |       do_benchmark
#  10.78%  12.6888s  | | |         main
#   0.07%  80.087ms  | | relu_forward
#   0.07%  80.087ms  | | | net_forward
#   0.07%  80.087ms  | | |   net_classify
#   0.07%  80.087ms  | | |     run_classification
#   0.07%  80.087ms  | | |       do_benchmark
#   0.07%  80.087ms  | | |         main
#   0.04%  45.049ms  | | pool_forward
#   0.04%  45.049ms  | |   net_forward
#   0.04%  45.049ms  | |     net_classify
#   0.04%  45.049ms  | |       run_classification
#   0.04%  45.049ms  | |         do_benchmark
#   0.04%  45.049ms  | |           main
#   0.20%  235.26ms  | volume_set
#   0.08%  90.098ms  |   load_batch
#   0.08%  90.098ms  |   | run_classification
#   0.08%  90.098ms  |   |   do_benchmark
#   0.08%  90.098ms  |   |     main
#   0.04%  50.055ms  |   relu_forward
#   0.04%  50.055ms  |   | net_forward
#   0.04%  50.055ms  |   |   net_classify
#   0.04%  50.055ms  |   |     run_classification
#   0.04%  50.055ms  |   |       do_benchmark
#   0.04%  50.055ms  |   |         main
#   0.04%  50.055ms  |   conv_forward
#   0.04%  50.055ms  |   | net_forward
#   0.04%  50.055ms  |   |   net_classify
#   0.04%  50.055ms  |   |     run_classification
#   0.04%  50.055ms  |   |       do_benchmark
#   0.04%  50.055ms  |   |         main
#   0.03%  40.044ms  |   make_volume
#   0.03%  40.044ms  |   | load_batch
#   0.03%  40.044ms  |   |   run_classification
#   0.03%  40.044ms  |   |     do_benchmark
#   0.03%  40.044ms  |   |       main
#   0.00%  5.0055ms  |   pool_forward
#   0.00%  5.0055ms  |     net_forward
#   0.00%  5.0055ms  |       net_classify
#   0.00%  5.0055ms  |         run_classification
#   0.00%  5.0055ms  |           do_benchmark
#   0.00%  5.0055ms  |             main
#   8.53%   10.036s  conv_forward
#   8.53%   10.036s  | net_forward
#   8.53%   10.036s  |   net_classify
#   8.53%   10.036s  |     run_classification
#   8.53%   10.036s  |       do_benchmark
#   8.53%   10.036s  |         main
#   1.37%  1.61176s  ???
#   1.37%  1.60675s  | volume_get
#   1.36%  1.60175s  | | conv_forward
#   1.36%  1.60175s  | | | net_forward
#   1.36%  1.60175s  | | |   net_classify
#   1.36%  1.60175s  | | |     run_classification
#   1.36%  1.60175s  | | |       do_benchmark
#   1.36%  1.60175s  | | |         main
#   0.00%  5.0055ms  | | pool_forward
#   0.00%  5.0055ms  | |   net_forward
#   0.00%  5.0055ms  | |     net_classify
#   0.00%  5.0055ms  | |       run_classification
#   0.00%  5.0055ms  | |         do_benchmark
#   0.00%  5.0055ms  | |           main
#   0.00%  5.0055ms  | volume_set
#   0.00%  5.0055ms  |   relu_forward
#   0.00%  5.0055ms  |     net_forward
#   0.00%  5.0055ms  |       net_classify
#   0.00%  5.0055ms  |         run_classification
#   0.00%  5.0055ms  |           do_benchmark
#   0.00%  5.0055ms  |             main
#   0.43%  500.55ms  volume_set
#   0.17%  195.21ms  | make_volume
#   0.17%  195.21ms  | | load_batch
#   0.17%  195.21ms  | |   run_classification
#   0.17%  195.21ms  | |     do_benchmark
#   0.17%  195.21ms  | |       main
#   0.09%  100.11ms  | conv_forward
#   0.09%  100.11ms  | | net_forward
#   0.09%  100.11ms  | |   net_classify
#   0.09%  100.11ms  | |     run_classification
#   0.09%  100.11ms  | |       do_benchmark
#   0.09%  100.11ms  | |         main
#   0.08%  90.098ms  | relu_forward
#   0.08%  90.098ms  | | net_forward
#   0.08%  90.098ms  | |   net_classify
#   0.08%  90.098ms  | |     run_classification
#   0.08%  90.098ms  | |       do_benchmark
#   0.08%  90.098ms  | |         main
#   0.05%  60.066ms  | load_batch
#   0.05%  60.066ms  | | run_classification
#   0.05%  60.066ms  | |   do_benchmark
#   0.05%  60.066ms  | |     main
#   0.04%  50.055ms  | pool_forward
#   0.04%  50.055ms  | | net_forward
#   0.04%  50.055ms  | |   net_classify
#   0.04%  50.055ms  | |     run_classification
#   0.04%  50.055ms  | |       do_benchmark
#   0.04%  50.055ms  | |         main
#   0.00%  5.0055ms  | copy_volume
#   0.00%  5.0055ms  |   net_classify
#   0.00%  5.0055ms  |     run_classification
#   0.00%  5.0055ms  |       do_benchmark
#   0.00%  5.0055ms  |         main
#   0.14%  165.18ms  pool_forward
#   0.14%  165.18ms  | net_forward
#   0.14%  165.18ms  |   net_classify
#   0.14%  165.18ms  |     run_classification
#   0.14%  165.18ms  |       do_benchmark
#   0.14%  165.18ms  |         main
#   0.07%  80.087ms  load_batch
#   0.07%  80.087ms  | run_classification
#   0.07%  80.087ms  |   do_benchmark
#   0.07%  80.087ms  |     main
#   0.05%  60.066ms  relu_forward
#   0.05%  60.066ms  | net_forward
#   0.05%  60.066ms  |   net_classify
#   0.05%  60.066ms  |     run_classification
#   0.05%  60.066ms  |       do_benchmark
#   0.05%  60.066ms  |         main
#   0.05%  60.066ms  read
#   0.05%  60.066ms  | _IO_file_underflow
#   0.04%  45.049ms  |   ???
#   0.04%  45.049ms  |   | _IO_fread
#   0.04%  45.049ms  |   |   load_batch
#   0.04%  45.049ms  |   |     run_classification
#   0.04%  45.049ms  |   |       do_benchmark
#   0.04%  45.049ms  |   |         main
#   0.01%  15.016ms  |   _IO_default_uflow
#   0.01%  15.016ms  |     ???
#   0.01%  15.016ms  |       __isoc99_fscanf
#   0.01%  10.011ms  |         conv_load
#   0.01%  10.011ms  |         | load_cnn_snapshot
#   0.01%  10.011ms  |         |   run_classification
#   0.01%  10.011ms  |         |     do_benchmark
#   0.01%  10.011ms  |         |       main
#   0.00%  5.0055ms  |         fc_load
#   0.00%  5.0055ms  |           load_cnn_snapshot
#   0.00%  5.0055ms  |             run_classification
#   0.00%  5.0055ms  |               do_benchmark
#   0.00%  5.0055ms  |                 main
#   0.03%  35.038ms  make_volume
#   0.03%  35.038ms  | load_batch
#   0.03%  35.038ms  |   run_classification
#   0.03%  35.038ms  |     do_benchmark
#   0.03%  35.038ms  |       main
#   0.01%  10.011ms  fc_forward
#   0.01%  10.011ms  | net_forward
#   0.01%  10.011ms  |   net_classify
#   0.01%  10.011ms  |     run_classification
#   0.01%  10.011ms  |       do_benchmark
#   0.01%  10.011ms  |         main
#   0.01%  10.011ms  copy_volume
#   0.01%  10.011ms  | net_classify
#   0.01%  10.011ms  |   run_classification
#   0.01%  10.011ms  |     do_benchmark
#   0.01%  10.011ms  |       main
#   0.01%  10.011ms  __restore_rt
#   0.01%  10.011ms  | read
#   0.01%  10.011ms  |   _IO_file_underflow
#   0.01%  10.011ms  |     ???
#   0.01%  10.011ms  |       _IO_fread
#   0.01%  10.011ms  |         load_batch
#   0.01%  10.011ms  |           run_classification
#   0.01%  10.011ms  |             do_benchmark
#   0.01%  10.011ms  |               main
#   0.00%  5.0055ms  malloc
#   0.00%  5.0055ms    make_volume
#   0.00%  5.0055ms      load_batch
#   0.00%  5.0055ms        run_classification
#   0.00%  5.0055ms          do_benchmark
#   0.00%  5.0055ms            main
#   ```
